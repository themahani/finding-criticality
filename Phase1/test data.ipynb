# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("main_data.csv")
df
# Out:
#       Unnamed: 0  # of bumps  # of inflections  curvature  min i  max i  \
# 0              0           3                 0   3.255230     38     31
# 1              1           0                 0   1.404121     39     34
# 2              2           0                 0  -7.082191      6      0
# 3              3           1                 0  -8.379891     22      0
# 4              4           1                 0 -13.070105     36     36
# ...          ...         ...               ...        ...    ...    ...
# 8793        8793           0                 0  -1.873302     59     63
# 8794        8794           0                 0  -1.102228     53     65
# 8795        8795           1                 0  -0.846527     67     71
# 8796        8796           0                 0  -1.016451     66     67
# 8797        8797           0                 0   0.743810     68     72
#
#          x min     x max      y min      y max         S  criticality
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   # of bumps  # of inflections    curvature        min i  \
# count  8798.000000  8798.000000            8798.0  8211.000000  8798.000000
# mean   4398.500000     0.720050               0.0     0.378005    40.375767
# std    2539.908168     0.934691               0.0     9.313020    23.955492
# min       0.000000     0.000000               0.0  -193.133647    -1.000000
# 25%    2199.250000     0.000000               0.0    -2.023355    26.000000
# 50%    4398.500000     0.000000               0.0     0.325468    44.000000
# 75%    6597.750000     1.000000               0.0     2.559903    61.000000
# max    8797.000000     6.000000               0.0    81.389296   580.000000
#
#              max i        x min        x max        y min        y max  \
# count  8798.000000  8798.000000  8798.000000  8798.000000  8798.000000
# mean     44.501591     4.994117     5.131249   -11.498190    -7.863955
# ...
